# %%
##This is task 2##
import pandas as pd
import numpy as np
df=pd.read_csv('D2.csv')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1130 entries, 0 to 1129
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   country               1130 non-null   object
#  1   region                1130 non-null   object
#  2   date                  1130 non-null   object
#  3   retail                939 non-null    float64
#  4   grocery_and_pharmacy  942 non-null    float64
#  5   parks                 884 non-null    float64
#  6   transit_stations      939 non-null    float64
#  7   workplaces            1130 non-null   int64
#  8   residential           881 non-null    float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 79.6+ KB
# None

# %%
df['date']=pd.to_datetime(df['date'])
df["retail"] = df["retail"].fillna("0").astype(int)
df["grocery_and_pharmacy"] = df["grocery_and_pharmacy"].fillna("0").astype(int)
df["parks"] = df["parks"].fillna("0").astype(int)
df["transit_stations"] = df["transit_stations"].fillna("0").astype(int)
df["workplaces"] = df["workplaces"].fillna("0").astype(int)
df["residential"] = df["residential"].fillna("0").astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1130 entries, 0 to 1129
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   country               1130 non-null   object
#  1   region                1130 non-null   object
#  2   date                  1130 non-null   datetime64[ns]
#  3   retail                1130 non-null   int32
#  4   grocery_and_pharmacy  1130 non-null   int32
#  5   parks                 1130 non-null   int32
#  6   transit_stations      1130 non-null   int32
#  7   workplaces            1130 non-null   int32
#  8   residential           1130 non-null   int32
# dtypes: datetime64[ns](1), int32(6), object(2)
# memory usage: 53.1+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

df2 = df[['retail', 'grocery_and_pharmacy', 'parks','transit_stations','workplaces','residential']]
X = df2.to_numpy()
scaler = StandardScaler()
X = scaler.fit_transform(X)
rs=4
clusters = []
inertia_vals = []
for k in range(2, 15, 2):
 model = KMeans(n_clusters=k, random_state=rs, n_jobs=10)
 model.fit(X)
 clusters.append(model)
 inertia_vals.append(model.inertia_)

# %%
plt.plot(range(2,15,2), inertia_vals, marker='*')
plt.show()

# %%
from sklearn.metrics import silhouette_score
print(clusters[1])
print("Silhouette score for k=4", silhouette_score(X, clusters[1].predict(X)))
print(clusters[2])
print("Silhouette score for k=6", silhouette_score(X, clusters[2].predict(X)))
print(clusters[3])
print("Silhouette score for k=8", silhouette_score(X, clusters[3].predict(X)))
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=10, precompute_distances='auto',
#        random_state=4, tol=0.0001, verbose=0)
# Silhouette score for k=4 0.259920896334751
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=6, n_init=10, n_jobs=10, precompute_distances='auto',
#        random_state=4, tol=0.0001, verbose=0)
# Silhouette score for k=6 0.2965856906570361
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=8, n_init=10, n_jobs=10, precompute_distances='auto',
#        random_state=4, tol=0.0001, verbose=0)
# Silhouette score for k=8 0.3094900832070329

# %%
model = KMeans(n_clusters=4, random_state=rs)
model.fit(X)
# sum of intra-cluster distances
print("Sum of intra-cluster distance:", model.inertia_)
print("Centroid locations:")
for centroid in model.cluster_centers_:
 print(centroid)
y = model.predict(X)
df2['Cluster_ID'] = y
# how many in each
print("Cluster membership")
print(df2['Cluster_ID'].value_counts())
# pairplot
# added alpha value to assist with overlapping points
cluster_g = sns.pairplot(df2, hue='Cluster_ID', diag_kind='hist')
plt.show()
# Out:
# Sum of intra-cluster distance: 2474.171012797757
# Centroid locations:
# [ 1.4416939   1.04018195  0.49232901  1.44382014  0.82429688 -1.27559788]
# [-0.54638145 -0.33327904 -0.09745568 -0.34167601 -0.46287049  0.29118349]
# [-1.05452203 -1.2846908  -1.1964263  -1.01631862 -0.82335487  1.09379864]
# [ 0.3812274   0.64168035  0.72626141  0.07628436  0.60495838 -0.22048813]
# Cluster membership
# 1    370
# 3    280
# 0    241
# 2    239
# Name: Cluster_ID, dtype: int64
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df3=df[(df['country']=='Australia')|(df['country']=='United Kingdom')|(df['country']=='Japan')|(df['country']=='Latvia')|(df['country']=='Romania')|(df['country']=='Slovenia')|(df['country']=='Kenya')]
df3.head(10)
# Out:
#             country                        region       date  retail  \
# 46        Australia                         Total 2020-04-16     -39
# 47        Australia  Australian Capital Territory 2020-04-16     -37
# 48        Australia               New South Wales 2020-04-16     -40
# 49        Australia            Northern Territory 2020-04-16     -20
# 50        Australia                    Queensland 2020-04-16     -34
# 51        Australia               South Australia 2020-04-16     -32
# 52        Australia                      Tasmania 2020-04-16     -50
# 53        Australia                      Victoria 2020-04-16     -45
# 54        Australia             Western Australia 2020-04-16     -32
# 299  United Kingdom                         Total 2020-04-16     -73
#
#      grocery_and_pharmacy  parks  transit_stations  workplaces  residential
# 46                     -8    -27               -60         -41           20
# ...

# %%
df4 = df3[['retail', 'grocery_and_pharmacy', 'parks','transit_stations','workplaces','residential']]
X = df4.to_numpy()
scaler = StandardScaler()
X = scaler.fit_transform(X)
rs=4
clusters = []
inertia_vals = []
for k in range(2, 15, 2):
 model = KMeans(n_clusters=k, random_state=rs, n_jobs=10)
 model.fit(X)
 clusters.append(model)
 inertia_vals.append(model.inertia_)

# %%
plt.plot(range(2,15,2), inertia_vals, marker='*')
plt.show()

# %%
model = KMeans(n_clusters=4, random_state=rs)
model.fit(X)
# sum of intra-cluster distances
print("Sum of intra-cluster distance:", model.inertia_)
print("Centroid locations:")
for centroid in model.cluster_centers_:
 print(centroid)
y = model.predict(X)
df4['Cluster_ID'] = y
# how many in each
print("Cluster membership")
print(df4['Cluster_ID'].value_counts())
# pairplot
# added alpha value to assist with overlapping points
cluster_g = sns.pairplot(df4, hue='Cluster_ID', diag_kind='hist')
plt.show()
# Out:
# Sum of intra-cluster distance: 643.378071912505
# Centroid locations:
# [-1.05718168 -0.96043141  0.02294256 -0.9307253  -0.94546993  1.18932265]
# [ 0.68905043  1.14977914  0.92547334  0.10477415  1.64773293 -0.40451543]
# [-0.45766339 -0.42881755 -0.93038512 -0.40611813 -0.22379351 -0.04700202]
# [ 1.22242016  0.82192667  0.30426086  1.36726206  0.3293263  -1.06775189]
# Cluster membership
# 0    122
# 3    108
# 2    100
# 1     62
# Name: Cluster_ID, dtype: int64
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
